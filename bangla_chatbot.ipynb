# %%
# imports
import json
from tensorflow import keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
# read files
def read_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data
# load files
train_data = read_json('./dataset/train.json')
test_data = read_json('./dataset/test.json')
validation_data = read_json('./dataset/validation.json')

print("First validation example:")
print(train_data['data'][0])
# Out:
# First validation example:
# {'title': 'Normans', 'paragraphs': [{'qas': [{'question': 'কোন দেশে নরম্যান্ডি অবস্থিত?', 'id': '56ddde6b9a695914005b9628', 'answers': [{'text': 'ফ্রান্স', 'answer_start': 103}, {'text': 'ফ্রান্স', 'answer_start': 103}, {'text': 'ফ্রান্স', 'answer_start': 103}, {'text': 'ফ্রান্স', 'answer_start': 103}]}, {'question': 'নরমান্ডিতে নরম্যানরা কখন ছিল?', 'id': '56ddde6b9a695914005b9629', 'answers': [{'text': 'দশম এবং একাদশ শতাব্দীতে', 'answer_start': 79}, {'text': 'দশম এবং একাদশ শতাব্দীতে', 'answer_start': 79}, {'text': 'দশম এবং একাদশ শতাব্দীতে', 'answer_start': 79}, {'text': 'দশম এবং একাদশ শতাব্দীতে', 'answer_start': 79}]}, {'question': 'কোন দেশ থেকে নর্সের উৎপত্তি হয়েছিল?', 'id': '56ddde6b9a695914005b962a', 'answers': [{'text': 'ডেনমার্ক, আইসল্যান্ড এবং নরওয়ে', 'answer_start': 182}, {'text': 'ডেনমার্ক, আইসল্যান্ড এবং নরওয়ে', 'answer_start': 182}, {'text': 'ডেনমার্ক, আইসল্যান্ড এবং নরওয়ে', 'answer_start': 182}, {'text': 'ডেনমার্ক, আইসল্যান্ড এবং নরওয়ে', 'answer_start': 182}]}, {'question': 'নর্স নেতা কে ছিলেন?', 'id': '56ddde6b9a695914005b962b', 'answers': [{'text': 'রোলো', 'answer_start': 281}, {'text': 'রোলো', 'answer_start': 281}, {'text': 'রোলো', 'answer_start': 281}, {'text': 'রোলো', 'answer_start': 281}]}, {'question': 'নরম্যানরা প্রথম কোন শতাব্দীতে তাদের আলাদা পরিচয় লাভ করেছিল?', 'id': '56ddde6b9a695914005b962c', 'answers': [{'text': 'দশম', 'answer_start': 622}, {'text': 'দশম', 'answer_start': 622}]}, {'question': '১০০০ ও ১১০০-র দশকে যারা নরম্যান্ডিকে তাদের নাম দিয়েছিল', 'id': '5ad39d53604f3c001a3fe8d1', 'answers': []}, {'question': 'ফ্রান্স কোন অঞ্চলের?', 'id': '5ad39d53604f3c001a3fe8d2', 'answers': []}, {'question': '৩. রাজা চার্লস ৩য় কে মিথ্যা শপথ করেছিলেন?', 'id': '5ad39d53604f3c001a3fe8d3', 'answers': []}, {'question': 'কখন ফ্রাঙ্কিশ পরিচয়ের আবির্ভাব ঘটে?', 'id': '5ad39d53604f3c001a3fe8d4', 'answers': []}], 'context': 'নর্মানরা (নর্মান: নুরমান্দ; ফরাসি: নরমান্ড; লাতিন: নরমান্নি) ছিল সেই জাতি যারা দশম এবং একাদশ শতাব্দীতে ফ্রান্সের একটি অঞ্চল নরমান্ডিতে তাদের নাম দিয়েছিল। তারা নর্স ("নরম্যান" এসেছে ডেনমার্ক, আইসল্যান্ড এবং নরওয়ে থেকে আগত "নর্সম্যান") হানাদার এবং জলদস্যুদের থেকে, যারা তাদের নেতা রোলোর অধীনে পশ্চিম ফ্রান্সিয়ার রাজা তৃতীয় চার্লসের কাছে আনুগত্যের শপথ নিতে সম্মত হয়েছিল। প্রজন্মের পর প্রজন্ম ধরে স্থানীয় ফ্রাঙ্কিশ এবং রোমান-গৌলিশ জনগোষ্ঠীর সাথে মিশে যাওয়ার মাধ্যমে, তাদের বংশধররা ধীরে ধীরে পশ্চিম ফ্রান্সিয়ার ক্যারোলিনজিয়ান-ভিত্তিক সংস্কৃতির সাথে মিশে যাবে। নর্মানদের স্বতন্ত্র সাংস্কৃতিক ও জাতিগত পরিচয় প্রথম দিকে দশম শতাব্দীর প্রথমার্ধে উদ্ভূত হয়েছিল এবং পরবর্তী শতাব্দীগুলিতে এটি বিবর্তিত হতে থাকে।'}, {'qas': [{'question': 'হেস্টিংসের যুদ্ধের নায়ক কে ছিলেন?', 'id': '56dddf4066d3e219004dad5f', 'answers': [{'text': 'উইলিয়াম দ্য কনকিউররের', 'answer_start': 949}, {'text': 'উইলিয়াম দ্য কনকিউররের', 'answer_start': 949}, {'text': 'উইলিয়াম দ্য কনকিউররের', 'answer_start': 949}]}, {'question': 'নর্মানরা কোন ধর্ম পালন করত', 'id': '56dddf4066d3e219004dad61', 'answers': [{'text': 'ক্যাথলিক', 'answer_start': 212}, {'text': 'ক্যাথলিক অর্থোডক্সির', 'answer_start': 212}, {'text': 'ক্যাথলিক', 'answer_start': 212}]}, {'question': 'আধুনিক ইউরোপের ওপর নর্মান রাজবংশের কোন ধরনের বড় প্রভাব পড়েছিল?', 'id': '5ad3a266604f3c001a3fea27', 'answers': []}, {'question': 'তাদের খ্রিস্টীয় আত্মার জন্য কে বিখ্যাত ছিল?', 'id': '5ad3a266604f3c001a3fea28', 'answers': []}, {'question': 'কে রোমীয় ভাষা গ্রহণ করেছিল?', 'id': '5ad3a266604f3c001a3fea29', 'answers': []}, {'question': 'নরম্যান্ডির দেশ কে শাসন করেছে?', 'id': '5ad3a266604f3c001a3fea2a', 'answers': []}, {'question': 'বিজয়ী উইলিয়াম কোন রাজ্য খুঁজে পেয়েছিলেন?', 'id': '5ad3a266604f3c001a3fea2b', 'answers': []}], 'context': 'মধ্যযুগীয় ইউরোপ এবং এমনকি নিকট প্রাচ্যের উপর নর্মান রাজবংশের একটি প্রধান রাজনৈতিক, সাংস্কৃতিক এবং সামরিক প্রভাব ছিল। নরমানরা তাদের সামরিক মনোভাবের জন্য এবং অবশেষে তাদের খ্রিস্টীয় ভক্তির জন্য খ্যাতি লাভ করেছিল, ক্যাথলিক অর্থোডক্সির প্রবক্তা হয়ে উঠেছিল, যেখানে তারা অন্তর্ভুক্ত হয়েছিল। তারা বসতি স্থাপনকারী ফ্রাঙ্কিশ ভূমির গালো-রোমান্স ভাষা গ্রহণ কর ...
